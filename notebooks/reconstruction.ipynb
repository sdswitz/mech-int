# %%
import os
os.getcwd()
# Out:
# '/Users/samswitz/GitHub/mech-int/notebooks'

# %%
os.chdir("/Users/samswitz/GitHub/mech-int")

# %%
# !python scripts/eval_sae.py --checkpoint saved_models/sae_model_4x.pt
# Out:
# ---
# val_mse: 0.03629010605315367
# val_l0: 0.03768384849859609
# dead_features: 6
# dead_fraction: 0.0029296875
# training_seconds: 0.0
# total_seconds: 0.0
# num_features: 2048
# num_params: 2099712
# git_commit: 37a17cb
# checkpoint_path: saved_models/sae_model_4x.pt

# %%
# !python scripts/eval_sae.py --checkpoint saved_models/sae_model_8x.pt
# Out:
# ---
# val_mse: 0.019242984760138724
# val_l0: 0.05705774678952164
# dead_features: 4
# dead_fraction: 0.0009765625
# training_seconds: 0.0
# total_seconds: 0.0
# num_features: 4096
# num_params: 4198912
# git_commit: 37a17cb
# checkpoint_path: saved_models/sae_model_8x.pt

# %%
# !python scripts/eval_sae.py --checkpoint saved_models/sae_model_16x.pt
# Out:
# ---
# val_mse: 0.00840764102112088
# val_l0: 0.08274666965007782
# dead_features: 4
# dead_fraction: 0.00048828125
# training_seconds: 0.0
# total_seconds: 0.0
# num_features: 8192
# num_params: 8397312
# git_commit: 37a17cb
# checkpoint_path: saved_models/sae_model_16x.pt

# %%
# !python scripts/eval_sae.py --checkpoint saved_models/sae_model_32x.pt
# Out:
# ---
# val_mse: 0.0036102234282427365
# val_l0: 0.08965600488914384
# dead_features: 1
# dead_fraction: 6.103515625e-05
# training_seconds: 0.0
# total_seconds: 0.0
# num_features: 16384
# num_params: 16794112
# git_commit: 37a17cb
# checkpoint_path: saved_models/sae_model_32x.pt
