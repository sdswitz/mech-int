# %%
import os
os.chdir(os.path.join(os.path.dirname("__file__"), "../.."))

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import pandas as pd
import matplotlib.pyplot as plt
import tqdm

from transformers import AutoTokenizer

# %%
EXPANSION = 8

# %%
metrics = pd.read_csv(f"training_metrics/training_metrics_{EXPANSION}x.csv")

# %%
# plot the metrics
plt.figure(figsize=(12, 8))
plt.suptitle(f'Training Metrics for Expansion Factor {EXPANSION}')
plt.subplot(2, 2, 1)
plt.plot(metrics['mse'])
plt.title('MSE Loss')
plt.subplot(2, 2, 2)
plt.plot(metrics['l1'])
plt.title('L1 Norm of Activations')
plt.subplot(2, 2, 3)
plt.plot(metrics['l0'])
plt.title('L0 Norm of Activations')
plt.subplot(2, 2, 4)
plt.plot(metrics['loss'])
plt.title('Total Loss')
plt.tight_layout()
plt.show()

# %%
from sae import SparseAutoEncoder
from datasets import load_dataset

# Load tokenizer only (no need for the full model)
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-70m")

MODEL_PATH = f"saved_models/sae_model_{EXPANSION}x.pt"

# Load saved SAE
d = 512
m = d * EXPANSION
sae = SparseAutoEncoder(d=d, m=m)
sae.load_state_dict(torch.load(MODEL_PATH, map_location="cpu"))
sae.eval()

# Load activations and process through SAE encoder in batches
# Full encoder output would be ~88GB, so we process in chunks
NUM_TEXTS = 50000
ACTIVATIONS_PATH = f"activations/activations_{NUM_TEXTS}.pt"

activations = torch.load(ACTIVATIONS_PATH, map_location="cpu")
n_tokens = activations.shape[0]
BATCH_SIZE = 4096

# We only need top-k per feature, so we track running top-k instead of storing everything
K = 20  # track top-K activating tokens per feature
top_vals = torch.zeros(m, K)
top_idxs = torch.full((m, K), -1, dtype=torch.long)

with torch.no_grad():
    for start in tqdm.trange(0, n_tokens, BATCH_SIZE):
        batch = activations[start:start + BATCH_SIZE]
        feat_acts = sae.encoder(batch)  # (batch, m)

        for j in range(feat_acts.shape[1]):
            combined_vals = torch.cat([top_vals[j], feat_acts[:, j]])
            combined_idxs = torch.cat([top_idxs[j], torch.arange(start, start + feat_acts.shape[0])])
            best = combined_vals.topk(K)
            top_vals[j] = best.values
            top_idxs[j] = combined_idxs[best.indices]

del activations

# Re-tokenize the same texts to get token strings
# TransformerLens prepends a BOS token per text, so we must do the same
dataset = load_dataset("openwebtext", split="train", streaming=True)
BOS = tokenizer.bos_token_id

all_tokens = []
all_contexts = []
for i, example in enumerate(tqdm.tqdm(dataset, total=NUM_TEXTS)):
    if i >= NUM_TEXTS:
        break
    text = example["text"][:512]
    token_ids = [BOS] + tokenizer.encode(text, add_special_tokens=False)
    tokens = [tokenizer.decode(tid) for tid in token_ids]
    for t in tokens:
        all_tokens.append(t)
        all_contexts.append(text)

print(f"Total tokens: {len(all_tokens)}, activations: {n_tokens}")
assert len(all_tokens) == n_tokens, f"Mismatch! tokens={len(all_tokens)} vs activations={n_tokens}"
print(f"Tracked top-{K} activations for {m} features")
# Out:
# 100%|██████████| 1437/1437 [06:28<00:00,  3.70it/s]
# 100%|██████████| 50000/50000 [00:30<00:00, 1660.65it/s]
# Total tokens: 5884867, activations: 5884867
# Tracked top-20 activations for 4096 features

# %%
def inspect_feature(feature_idx, k=10):
    k = min(k, K)
    vals = top_vals[feature_idx, :k]
    idxs = top_idxs[feature_idx, :k]

    print(f"Feature {feature_idx} — top {k} activating tokens:\n")
    for val, idx in zip(vals, idxs):
        idx = idx.item()
        if idx < 0:
            break
        token = all_tokens[idx]
        context = all_contexts[idx]
        print(f"  {val:.3f}  token={repr(token):>15s}   context: {context[:80]}")

# try a few features
inspect_feature(2)
print()
inspect_feature(100)
# Out:
# Feature 2 — top 10 activating tokens:
#
#   2.194  token=         ' Feb'   context: Peter G. Aiken/Getty Images
#
# The Cleveland Browns have endured another regime ch
#   2.157  token=         ' Feb'   context: SEX, LOVE & HEALTH A-FAIRE
#
# Monday, Feb. 10, 2014
#
# Sac City Student Center
#
# 12 n
#   2.148  token=         ' Feb'   context: Frank Victores/Associated Press
#
# Cincinnati Bengals tight end Tyler Eifert suffe
#   2.129  token=         ' Feb'   context: LGBT ATL turns on its heart lights. Whether you’re courting a sweetie, consideri
#   2.129  token=         ' Feb'   context: Deanna Durante was in court during the "Black Madam" trial. Find out who the she
#   2.091  token=         ' Feb'   context: NYPD auxiliary officers James Kiernan (left) and Jordan Martinez are accused of
#   2.056  token=         ' Feb'   context: Buy Photo Thomas Earl Crossley holds his sons old ASU baseball jersey as his wif
#   2.055  token=         ' Feb'   context: The Winter Olympics is coming! In an inspired move, NBC has enlisted Game of Thr
#   2.044  token=         ' Feb'   context: Two North Texas women opened a repair shop to give women what they've been askin
#   2.041  token=         ' Feb'   context: Yosemite blueprint outlines future of iconic park
#
# FILE - In this Oct. 17, 2013
#
# Feature 100 — top 10 activating tokens:
#
#   6.321  token=        ' able'   context: #508 & #509: Friendship, Attachment Styles & Boundaries
#
# This is the last day of
#   6.211  token=        ' able'   context: Image: Chris Jordan/US FWS
#
# Oceans are the world's forgotten landfill, and seabi
#   6.128  token=        ' able'   context: Eveline Widmer-Schlumpf believes citizens will rely on facts before casting thei
#   6.065  token=        ' able'   context: Brazil - The Last WC Before FIFA Abandons Morality?
#
# For all the problems that w
#   6.064  token=        ' able'   context: WASHINGTON, DC — A view of Nationals Park from the Hampton Inn’s Top of the Yard
#   6.048  token=        ' able'   context: After a lone gunman at an Oregon community college opened fire and killed ten pe
#   6.048  token=        ' able'   context: Syracuse, NY - Time Warner Cable is raising the price of its Internet service, b
#   6.046  token=        ' able'   context: Cristiano Ronaldo‘s looming transfer saga further proves that soccer is a “money
#   6.044  token=        ' able'   context: ADVERTISEMENT
#
# “I don’t want to be melodramatic but I do want to be truthful. I
#   6.042  token=        ' able'   context: Better Know A Supporters Group - Section 8 (Chicago Fire)
#
# We continue our compr

# %%
# Features where the best activation is 0 are dead
alive_mask = top_vals[:, 0] > 0
dead_count = (~alive_mask).sum().item()

# Sort alive features by their top activation (lowest = sparsest)
alive_idxs = torch.where(alive_mask)[0]
sorted_order = top_vals[alive_idxs, 0].argsort()
sparsest_idxs = alive_idxs[sorted_order]

print(f"Dead features: {dead_count} / {m}")
print()
for idx in sparsest_idxs[:10]:
    idx = idx.item()
    # Count non-zero entries in top-K as a proxy
    n_active = (top_vals[idx] > 0).sum().item()
    print(f"Feature {idx}: top activation = {top_vals[idx, 0]:.4f} ({n_active}/{K} top slots active)")
    inspect_feature(idx, k=5)
    print()
# Out:
# Dead features: 4 / 4096
#
# Feature 1846: top activation = 0.0017 (1/20 top slots active)
# Feature 1846 — top 5 activating tokens:
#
#   0.002  token=          ' 10'   context: At 10 o’clock in the evening we arrived. The train stopped. We went onto the pla
#
# Feature 3638: top activation = 0.0057 (1/20 top slots active)
# Feature 3638 — top 5 activating tokens:
#
#   0.006  token=        ' held'   context: BAGHDAD — As Iraq emerges from three years of war with the Islamic State group,
#
# Feature 691: top activation = 0.0068 (1/20 top slots active)
# Feature 691 — top 5 activating tokens:
#
#   0.007  token=        ' like'   context: Formula 1's omnipresent pursuit of safety usually remains under the radar and it
#
# Feature 1233: top activation = 0.0082 (4/20 top slots active)
# Feature 1233 — top 5 activating tokens:
#
#   0.008  token=      ' series'   context: While popular documentary films like Fahrenheit 9/11 and No End In Sight explore
#   0.005  token=            '0'   context: Cornucopia 0.3.3 - Legendaries, MI's, Relics and more! Grim Dawn: Cornucopia v0.
#   0.004  token=           ' a'   context: WASHINGTON — President Obama will pronounce on the state of the union for the fi
#   0.001  token=        ' like'   context: Next Chapter >
#
# In terms of car-related shops, I’ve yet to experience anything q
#
# Feature 1908: top activation = 0.0082 (2/20 top slots active)
# Feature 1908 — top 5 activating tokens:
#
#   0.008  token=        ' 1996'   context: Ady Pennock spent seven years of his playing career at Gillingham, from 1996-200
#   0.002  token=     ' loyalty'   context: Sally Nightingale is a woman who knows the meaning both of loyalty and sacrifice
#
# Feature 1063: top activation = 0.0102 (1/20 top slots active)
# Feature 1063 — top 5 activating tokens:
#
#   0.010  token=         ' its'   context: ESB and Vodafone joint venture Siro has dropped out of the Government’s National
#
# Feature 2376: top activation = 0.0102 (2/20 top slots active)
# Feature 2376 — top 5 activating tokens:
#
#   0.010  token=          ' to'   context: As many of you know, I’m currently on a 16-city tour to promote my new book, You
#   0.009  token=          ' of'   context: In this week’s Backpage, football writer and FIFA fan Darren Cross looks at all
#
# Feature 392: top activation = 0.0111 (3/20 top slots active)
# Feature 392 — top 5 activating tokens:
#
#   0.011  token=  ' population'   context: A young man in a T-shirt who was standing next to us at the paan stall asked, “W
#   0.008  token=      ' offers'   context: Charlie Sheen offers advice to Johnny Manziel
#
# Click through the gallery to reli
#   0.000  token=  ' population'   context: Lounès Matoub (Kabyle: Lwennas Meɛṭub; Berber languages: ⵍⵡⴻⵏⵏⴰⵙ ⵎⴻⵄⵜⵓⴱ or ⵎⵄⵟⵓⴱ
#
# Feature 3078: top activation = 0.0125 (1/20 top slots active)
# Feature 3078 — top 5 activating tokens:
#
#   0.013  token=        ' have'   context: From now on he’s going to have to do his pontificating.
#
# From BEHIND BARS.
#
# Poss
#
# Feature 3852: top activation = 0.0135 (2/20 top slots active)
# Feature 3852 — top 5 activating tokens:
#
#   0.013  token=           ' “'   context: Share. “In success, I think all those things would be possible." “In success, I
#   0.012  token=         ' the'   context: TORONTO – A taxi driver in Toronto has taken the cab industry’s heated battle ag

# %%
# Rank features by strongest top activation
best_per_feature = top_vals[:, 0]
ranked = best_per_feature.argsort(descending=True)

for rank, idx in enumerate(ranked[:20]):
    idx = idx.item()
    print(f"=== Rank {rank+1}: Feature {idx} (top activation: {best_per_feature[idx]:.3f}) ===")
    inspect_feature(idx, k=5)
    print()
# Out:
# === Rank 1: Feature 3289 (top activation: 168.386) ===
# Feature 3289 — top 5 activating tokens:
#
#   168.386  token=            '.'   context: Δραματικά είναι τα στοιχεία για την κατάσταση στην αγορά εργασίας στην χώρας μας
#   162.418  token=            '.'   context: Self-driving electric cars? Rad!! A Hyperloop train that can get you from New Yo
#   162.109  token=            '.'   context: Fox News Channel pundits Greta Van Susteren and Erick Erickson have gone to war
#   161.757  token=            '.'   context: According to court documents, 29-year-old Markus Kaarma of Missoula, Mont. was i
#   161.663  token=            '.'   context: Poison Ivy is a 1985 American made-for-television romantic comedy film starring
#
# === Rank 2: Feature 3348 (top activation: 28.609) ===
# Feature 3348 — top 5 activating tokens:
#
#   28.609  token=            '.'   context: At MWC 2016, OPPO released its new SmartSensor image stabilization technology. A
#   28.554  token=            '.'   context: A local police officer says it’s time to legalize marijuana. Dan Mulligan is als
#   28.547  token=            '.'   context: Square Enix held a quite eventful keynote during the Final Fantasy XIV Fan fest
#   28.544  token=            '.'   context: For the past 30 years, Shin and Tatsuko Okawara spent their lives working as org
#   28.536  token=            '.'   context: Dane Carbaugh, who edits the Blazers blog AYoungSabonis.com, will be providing t
#
# === Rank 3: Feature 1150 (top activation: 10.500) ===
# Feature 1150 — top 5 activating tokens:
#
#   10.500  token=            '’'   context: We’ve been working for some time—with your help—to ensure that improvidently gra
#   10.441  token=            '’'   context: Have you ever looked at a dog, splayed out on a living room floor, and thought,
#   10.286  token=            '’'   context: Pro-choicers clash with anti-choicers in North Carolina in 2012. Photo by Robyn
#   10.204  token=            '’'   context: Why Abortion is Moral
#
# All of the arguments against abortion boil down to six sp
#   10.187  token=            '’'   context: President Obama said Republican opposition to ObamaCare should disqualify them f
#
# === Rank 4: Feature 63 (top activation: 10.059) ===
# Feature 63 — top 5 activating tokens:
#
#   10.059  token=            '.'   context: Δραματικά είναι τα στοιχεία για την κατάσταση στην αγορά εργασίας στην χώρας μας
#   7.487  token=            '.'   context: Western Rite Orthodoxy, Western Orthodoxy, or Orthodox Western Rite are terms us
#   6.462  token=            '.'   context: Minister of Public Safety and Solicitor General Mike Farnworth told municipal le
#   6.301  token=            '.'   context: Poison Ivy is a 1985 American made-for-television romantic comedy film starring
#   6.194  token=            '.'   context: New York (CNN) -- A new prosecution document in the Dominique Strauss-Kahn case
#
# === Rank 5: Feature 1373 (top activation: 9.475) ===
# Feature 1373 — top 5 activating tokens:
#
#   9.475  token=            '’'   context: Our ancestors made their mark in caves, on stones leaving a record of their meth
#   9.430  token=            '’'   context: I assume I was aware of this when the new playoff formats were announced, but if
#   9.310  token=            '’'   context: A tech company called socialautopsy.com is preparing to launch, and things are a
#   9.209  token=            '’'   context: Nick Di Paolo unleashes on the celebrities who turned the SAG Awards into a prog
#   9.190  token=            '’'   context: Some of the great science fiction movies are timeless. In other words, their por
#
# === Rank 6: Feature 4044 (top activation: 9.390) ===
# Feature 4044 — top 5 activating tokens:
#
#   9.390  token=            '-'   context: Get the biggest daily news stories by email Subscribe Thank you for subscribing
#   9.290  token=            '-'   context: EUREKA, Calif. – Police arrested a suspect who allegedly shot a man using a shot
#   9.194  token=            '-'   context: ES News Email Enter your email address Please enter an email address Email addre
#   9.178  token=            '-'   context: Before being gunned down, in an apparent Islamic State-inspired terrorist attack
#   9.177  token=            '-'   context: VALLEJO — The alleged California Highway Patrol “game” of secretly trading expli
#
# === Rank 7: Feature 1437 (top activation: 8.958) ===
# Feature 1437 — top 5 activating tokens:
#
#   8.958  token=            '’'   context: Audi announced Thursday that Filipe Albuquerque will be joining the factory squa
#   8.542  token=            '’'   context: WASHINGTON—Congressional Republicans on Tuesday announced a new investigation in
#   8.520  token=            '’'   context: The American Civil Rights Union’s Robert Knight, who has been encouraging Republ
#   8.517  token=            '’'   context: S. Africa ruling party wants to pull out of ICC
#
# South Africa’s ruling party say
#   8.486  token=            '’'   context: Canada’s first female prime minister ripped into Republican presidential candida
#
# === Rank 8: Feature 1141 (top activation: 8.957) ===
# Feature 1141 — top 5 activating tokens:
#
#   8.957  token=            '�'   context: This video is no longer available
#
# This video was hosted on Vidme, which is no l
#   8.862  token=            '�'   context: This video is no longer available
#
# This video was hosted on Vidme, which is no l
#   8.797  token=            '�'   context: This video is no longer available
#
# This video was hosted on Vidme, which is no l
#   8.606  token=            '�'   context: This video is no longer available
#
# This video was hosted on Vidme, which is no l
#   8.418  token=            '�'   context: This video is no longer available
#
# This video was hosted on Vidme, which is no l
#
# === Rank 9: Feature 2061 (top activation: 8.831) ===
# Feature 2061 — top 5 activating tokens:
#
#   8.831  token=            'S'   context: Copyright 2019 Nexstar Broadcasting, Inc. All rights reserved. This material may
#   8.762  token=            'S'   context: Lawrence J. Joyce, an attorney and practicing pharmacist from Poplar Grove, says
#   8.684  token=            'S'   context: A Saudi man arrested at Detroit Metropolitan Airport after federal agents said h
#   8.663  token=            'S'   context: A Burnsville woman cannot hold Iowa State University responsible for her alleged
#   8.653  token=            'S'   context: A convicted child molester won his sentencing appeal and will not have to retroa
#
# === Rank 10: Feature 2034 (top activation: 8.735) ===
# Feature 2034 — top 5 activating tokens:
#
#   8.735  token=           ',”'   context: MONTREAL—Ben Scrivens is getting a chance to keep his NHL career alive with the
#   8.730  token=           ',”'   context: DENVER (CBS4)– The driver who struck and killed a young woman in downtown Denver
#   8.710  token=           ',”'   context: Share Pinterest
#
# Email
#
# Lance Stroll scored his first Formula 1 points with a st
#   8.640  token=           ',”'   context: Audi announced Thursday that Filipe Albuquerque will be joining the factory squa
#   8.636  token=           ',”'   context: Republican presidential candidate Donald Trump held a rally at Ladd-Peebles Stad
#
# === Rank 11: Feature 3311 (top activation: 8.592) ===
# Feature 3311 — top 5 activating tokens:
#
#   8.592  token=            '-'   context: A Connecticut teen's bucket list has gone viral following her tragic death earli
#   8.516  token=            '-'   context: The details emerged as Vince Li faced his murder trial by pleading not guilty.
#
#
#   8.507  token=            '-'   context: Following the largest case of its type in Denmark, in October 2014 Gottfrid Svar
#   8.496  token=            '-'   context: Hoddle Street killer Julian Knight loses High Court fight against laws keeping h
#   8.445  token=            '-'   context: VALLEJO — The alleged California Highway Patrol “game” of secretly trading expli
#
# === Rank 12: Feature 2000 (top activation: 8.424) ===
# Feature 2000 — top 5 activating tokens:
#
#   8.424  token=          ' un'   context: Hey guys, Welcome to the Official IW Avatar Design Contest!
#
# How does it work?
#
#
#   8.384  token=          ' un'   context: The man who wished to be eaten seemed quite shy when he walked into a Toronto ps
#   8.358  token=          ' un'   context: If you're waiting for someone who has to drive in San Francisco, especially arou
#   8.330  token=          ' un'   context: Two aspiring rappers from the rough streets of Washington, D.C. and its outer re
#   8.326  token=          ' un'   context: First edition (UK)
#
# The Incredible Journey (1961), by Scottish author Sheila Bur
#
# === Rank 13: Feature 3244 (top activation: 8.285) ===
# Feature 3244 — top 5 activating tokens:
#
#   8.285  token=          ' re'   context: As part of our collaboration with Elizabeth St gallery, FLINT is curating the wo
#   8.247  token=          ' re'   context: In the first instalment of a series on the threat of water scarcity, Pilita Clar
#   8.240  token=          ' re'   context: Fearing Death and Curing Aging
#
# You are going to die. It may take some time, but
#   8.164  token=          ' re'   context: UPDATE 2
#
# May 13, 2016
#
# Seed of Life is a meditative game in which you deflect c
#   8.145  token=          ' re'   context: “NO ONE,” the coach says to a locker room full of determined-looking young Ameri
#
# === Rank 14: Feature 3749 (top activation: 8.250) ===
# Feature 3749 — top 5 activating tokens:
#
#   8.250  token=           '\n'   context: You must sign in or register to continue reading content.
#
# EVERETT — The Majesti
#   8.243  token=           '\n'   context: Michelle Obama fed her husband's feud with Donald Trump on Friday as she gave a
#   8.236  token=           '\n'   context: A Chinese tycoon who raised eyebrows this week by traveling to New York with the
#   8.117  token=           '\n'   context: ISLAMABAD (AP) — Former Pakistani military ruler Pervez Musharraf fled court in
#   8.105  token=           '\n'   context: The governing Liberals are trying to hide documents related to the costly cancel
#
# === Rank 15: Feature 3568 (top activation: 8.200) ===
# Feature 3568 — top 5 activating tokens:
#
#   8.200  token=            '.'   context: In this 2008 photo, Lt. Gen. Raymond “Tony” Thomas talks with men in the Sulayma
#   8.158  token=            '.'   context: This graphic from NSA internal training materials, provided to The Washington Po
#   8.105  token=            '.'   context: The U.S. is suing Bank of America on behalf of Fannie Mae and Freddie Mac, with
#   8.096  token=            '.'   context: LANSING — Michigan lawmakers have voted to no longer require that someone be ins
#   8.094  token=            '.'   context: The world reacted with shock, awe and no small measure of disbelief as voters ma
#
# === Rank 16: Feature 2201 (top activation: 8.125) ===
# Feature 2201 — top 5 activating tokens:
#
#   8.125  token=           ' .'   context: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#   8.112  token=           ' .'   context: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#   8.094  token=           ' .'   context: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#   8.076  token=           ' .'   context: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#   8.063  token=           ' .'   context: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# === Rank 17: Feature 1154 (top activation: 8.030) ===
# Feature 1154 — top 5 activating tokens:
#
#   8.030  token=           ' U'   context: CLOSE Justin Mack and diversity reporter Stephanie Wang look ahead to what's nex
#   7.872  token=           ' U'   context: This morning, Martin Shkreli, elfin plague of the pharmaceutical world, was arre
#   7.862  token=           ' U'   context: CLOSE The State Department has issued a worldwide travel alert during the bigges
#   7.859  token=           ' U'   context: Marine Corps personnel move a transfer case containing the remains of Marine Cor
#   7.851  token=           ' U'   context: EPA says 1 million gallons of oil may have spilled in Mich. river, governor crit
#
# === Rank 18: Feature 432 (top activation: 8.001) ===
# Feature 432 — top 5 activating tokens:
#
#   8.001  token=            'G'   context: On the heels of the passage of mandatory genetically engineered (GE) food labeli
#   7.968  token=            'R'   context: SYDNEY (Reuters) - The United States has indicated it is open to a free trade ag
#   7.921  token=           'TT'   context: This article is a joint publication of Foreign Policy In Focus and TheNation.com
#   7.877  token=           'ES'   context: "ESRB" redirects here. For the European financial agency, see European Systemic
#   7.854  token=           'SP'   context: PETALING JAYA: Private car owners whose vehicles have been identified by the aut
#
# === Rank 19: Feature 3440 (top activation: 7.957) ===
# Feature 3440 — top 5 activating tokens:
#
#   7.957  token=      'Reuters'   context: March 13 (Reuters) - U.S. investigators suspect that Malaysia Airlines Flight 37
#   7.946  token=      'Reuters'   context: MANILA (Reuters) - The Philippine government derided Catholic bishops on Sunday
#   7.946  token=      'Reuters'   context: MANILA (Reuters) - Philippine Vice President Jejomar Binay on Monday vowed to am
#   7.924  token=      'Reuters'   context: DUBAI, April 4 (Reuters) - Iran has partially lifted a ban on women attending me
#   7.902  token=      'Reuters'   context: NEW YORK, July 6 (Reuters) - A former Goldman Sachs (GS.N) computer programmer a
#
# === Rank 20: Feature 975 (top activation: 7.753) ===
# Feature 975 — top 5 activating tokens:
#
#   7.753  token=        ' wasn'   context: Jennifer Tress begins a presentation at George Mason University with a photograp
#   7.633  token=        ' wasn'   context: A Designer’s Sublime Text Setup
#
# Matej Latin Blocked Unblock Follow Following De
#   7.606  token=        ' wasn'   context: Ross Ulbricht, convicted last February of being the mastermind behind the Silk R
#   7.573  token=        ' wasn'   context: Best of the Best: The Book Review has had its say; a few weeks ago, we named our
#   7.526  token=        ' wasn'   context: Sometimes checking a project one more time can be quite amusing. It helps to see

# %%
# Find the most "interpretable" features: ones where top-K tokens are consistent
# Score = fraction of top-K tokens that match the most common token
# Filter out single-char punctuation which dominates the max-activation ranking
from collections import Counter

BORING = {'.', "'", '-', '"', ',', '!', '?', ':', ';', '\n', ' ', ''}

scores = []
for feat_idx in range(m):
    idxs = top_idxs[feat_idx]
    valid = idxs[idxs >= 0]
    if len(valid) < 5:
        scores.append((feat_idx, 0.0, ""))
        continue
    tokens = [all_tokens[i.item()] for i in valid]
    counts = Counter(tokens)
    most_common_token, most_common_count = counts.most_common(1)[0]
    consistency = most_common_count / len(tokens)
    scores.append((feat_idx, consistency, most_common_token))

# Sort by consistency, filter out punctuation-only features
scores_filtered = [(idx, score, tok) for idx, score, tok in scores
                   if tok.strip() not in BORING and len(tok.strip()) > 0]
scores_filtered.sort(key=lambda x: -x[1])

print("Most consistent (interpretable) features:\n")
for feat_idx, consistency, top_token in scores_filtered[:30]:
    # if len(top_token) == 2:
    #     continue
    print(f"Feature {feat_idx}: {consistency:.0%} consistent, top token = {repr(top_token)}, max act = {top_vals[feat_idx, 0]:.3f}")
    inspect_feature(feat_idx, k=5)
    print()
# Out:
# Most consistent (interpretable) features:
#
# Feature 1: 100% consistent, top token = ' ca', max act = 1.808
# Feature 1 — top 5 activating tokens:
#
#   1.808  token=          ' ca'   context: Star forward Eddie Betts will be entertaining Crows fans for years to come after
#   1.757  token=          ' ca'   context: The family of Michael Brown appeared on NBC’s “Today” show, during which they we
#   1.752  token=          ' ca'   context: Credit: Marvel Comics
#
# Horror fiction icon R.L. Stine makes his comic book writi
#   1.740  token=          ' ca'   context: Twenty years after helping his injured son across the finish line in Barcelona,
#   1.722  token=          ' ca'   context: TO HEAR Gov. Larry Hogan (R) tell it, Maryland is sinking fast, its people fleei
#
# Feature 2: 100% consistent, top token = ' Feb', max act = 2.194
# Feature 2 — top 5 activating tokens:
#
#   2.194  token=         ' Feb'   context: Peter G. Aiken/Getty Images
#
# The Cleveland Browns have endured another regime ch
#   2.157  token=         ' Feb'   context: SEX, LOVE & HEALTH A-FAIRE
#
# Monday, Feb. 10, 2014
#
# Sac City Student Center
#
# 12 n
#   2.148  token=         ' Feb'   context: Frank Victores/Associated Press
#
# Cincinnati Bengals tight end Tyler Eifert suffe
#   2.129  token=         ' Feb'   context: LGBT ATL turns on its heart lights. Whether you’re courting a sweetie, consideri
#   2.129  token=         ' Feb'   context: Deanna Durante was in court during the "Black Madam" trial. Find out who the she
#
# Feature 3: 100% consistent, top token = ' after', max act = 5.623
# Feature 3 — top 5 activating tokens:
#
#   5.623  token=       ' after'   context: The top detective who was the first officer to dismiss sex abuse allegations aga
#   5.605  token=       ' after'   context: ADVERTISEMENT
#
# Kelly, who with Giffords runs Americans for Responsible Solutions
#   5.571  token=       ' after'   context: Sergei Polonsky is sent to Moscow after living for two years in a coastal town o
#   5.564  token=       ' after'   context: A server at a Carrabba's Italian Grill in Kansas was shocked to find a note left
#   5.549  token=       ' after'   context: Audio: NPR's Daniel Zwerdling reports on Senators' Demand for Army Discharge Pro
#
# Feature 6: 100% consistent, top token = 'It', max act = 5.314
# Feature 6 — top 5 activating tokens:
#
#   5.314  token=           'It'   context: It was towards the end of a long, cold, 2 month tour around Europe promoting my
#   5.314  token=           'It'   context: It began with a casually devestating pool shot. Then, the women of Chester turne
#   5.314  token=           'It'   context: It’s been a good week for Jay Z: the rap star chatted court-side with visiting r
#   5.314  token=           'It'   context: It’s been a while between articles posts, let’s get straight into it:
#
# Philosoph
#   5.314  token=           'It'   context: It’s Date Night with the Stoic Templum 2.1 !
#
# Unfortunately, that’s a date betwe
#
# Feature 7: 100% consistent, top token = ' should', max act = 5.578
# Feature 7 — top 5 activating tokens:
#
#   5.578  token=      ' should'   context: Fans of classics SEGA video games should remember the Space Harrier franchise we
#   5.427  token=      ' should'   context: South Africans should expect a fuel price increase of around 70 cents in Decembe
#   5.413  token=      ' should'   context: Movies should be made only on these events whereby all nations without exception
#   5.372  token=      ' should'   context: on March 28, 2017
#
# Take a minute and think about all the young people you know.
#   5.331  token=      ' should'   context: WikiLeaks has published 294,546 emails along with thousands of attached files fr
#
# Feature 8: 100% consistent, top token = ' e', max act = 3.820
# Feature 8 — top 5 activating tokens:
#
#   3.820  token=           ' e'   context: Anthology of Quitters is a selection of opening chapters from novels that were a
#   3.804  token=           ' e'   context: Sometimes things happen pretty fast in the NFL, and you don’t really notice them
#   3.792  token=           ' e'   context: The IRS announced on January 28th, that individual filers who use form 8863 for
#   3.791  token=           ' e'   context: When life is tumbling out of control, I go to my happy place, where I can dream,
#   3.787  token=           ' e'   context: GRAND RAPIDS, MI - Grand Rapids Community College is partnering with several con
#
# Feature 12: 100% consistent, top token = ' 7', max act = 2.538
# Feature 12 — top 5 activating tokens:
#
#   2.538  token=           ' 7'   context: A version of this article appeared on Medium.com
#
# On August 30th, 2016, the DEA
#   2.533  token=           ' 7'   context: Huawei has just unveiled its latest Honor smartphone, the 7i. The handset looks
#   2.526  token=           ' 7'   context: Investigators have disclosed that a diverted Air Canada Boeing 787-9's crew had
#   2.524  token=           ' 7'   context: Please enable Javascript to watch this video
#
# CHICAGO – Sheer panic erupted on a
#   2.516  token=           ' 7'   context: Foresight and cool-headed teamwork by pilots of a Royal New Zealand Air Force Bo
#
# Feature 14: 100% consistent, top token = ' fill', max act = 2.105
# Feature 14 — top 5 activating tokens:
#
#   2.105  token=        ' fill'   context: China has for long displayed signs of a classic stock market bubble. The dramati
#   2.063  token=        ' fill'   context: We're still two months away from real games, but it's never too early to examine
#   2.055  token=        ' fill'   context: Like the Simpsons before them, the Belchers are heading to the big screen. Deadl
#   1.995  token=        ' fill'   context: “He’s not fit to be my daughter’s boyfriend,” Dad declares after witnessing juni
#   1.984  token=        ' fill'   context: Economic Heartache
#
# Normally, consumers consider falling oil and gasoline prices
#
# Feature 15: 100% consistent, top token = ' duty', max act = 2.050
# Feature 15 — top 5 activating tokens:
#
#   2.050  token=        ' duty'   context: About This Game
#
# Last Stand This minigame allows you to skip the rest of the gam
#   1.960  token=        ' duty'   context: It is called Devi Krupa – the blessings of the goddess. But inside the modest si
#   1.830  token=        ' duty'   context: The crimes of North Korea’s regime are as chilling as those of the Nazis, South
#   1.814  token=        ' duty'   context: Apple on Friday responded to e-book price-fixing remedies proposed by the U.S. D
#   1.808  token=        ' duty'   context: At the Samsung Developer Conference (SDC), San Francisco, the company reveals it
#
# Feature 16: 100% consistent, top token = ' to', max act = 1.782
# Feature 16 — top 5 activating tokens:
#
#   1.782  token=          ' to'   context: New drunk-driving law cracks down on 3rd DUI LEGISLATURE
#
# Drivers who are repeat
#   1.726  token=          ' to'   context: Marijuana has come a long way in the nearly 14 years since the federal governmen
#   1.681  token=          ' to'   context: SAN FRANCISCO -- Oracle's situation in its intellectual property legal battle ag
#   1.677  token=          ' to'   context: A parliamentary inquiry has found strong opposition to the Government’s “unjusti
#   1.663  token=          ' to'   context: The National Park Service is still reviewing the group’s proposal, Russell Newel
#
# Feature 17: 100% consistent, top token = ' of', max act = 3.542
# Feature 17 — top 5 activating tokens:
#
#   3.542  token=          ' of'   context: The opening lines of Viceroy’s House, British director Gurinder Chadha’s epic ne
#   3.526  token=          ' of'   context: 13 SHARES Facebook Twitter Google Reddit Tumblr Digg Linkedin Stumbleupon Mail P
#   3.503  token=          ' of'   context: The Pirate Bay turns nine years old today, a truly remarkable achievement consid
#   3.484  token=          ' of'   context: The front page of today’s New York Times features an article titled Paths to War
#   3.483  token=          ' of'   context: In a conference call with reporters today, John McCain's lawyer John Dowd claime
#
# Feature 23: 100% consistent, top token = ' and', max act = 3.971
# Feature 23 — top 5 activating tokens:
#
#   3.971  token=         ' and'   context: Mayor Bill de Blasio’s non-lethal deer management plan for Staten Island provide
#   3.954  token=         ' and'   context: A new report by the Climate Commission of Australia, has admitted that whilst Ch
#   3.913  token=         ' and'   context: A gyro rotor | NASA
#
# If you’ve ever tried to give yourself a haircut, you know j
#   3.899  token=         ' and'   context: While Europe’s current crisis is grave indeed, the European project has broadly
#   3.892  token=         ' and'   context: Alan Partridge will be the BBC’s ‘voice of Brexit’ when he returns to the broadc
#
# Feature 27: 100% consistent, top token = 'erv', max act = 2.717
# Feature 27 — top 5 activating tokens:
#
#   2.717  token=          'erv'   context: Image copyright Science Photo Library
#
# Conservative plans to change social care
#   2.707  token=          'erv'   context: An oped was printed in Princeton University's newspaper this week attacking cons
#   2.700  token=          'erv'   context: EPIC! Laura Ingraham Gets 10 PM Slot on Fox News
#
# Conservative radio host and be
#   2.692  token=          'erv'   context: A conservative group filed suit on Monday seeking to remove special counsel Robe
#   2.690  token=          'erv'   context: Media playback is unsupported on your device Media caption Jose Manuel Barroso:
#
# Feature 28: 100% consistent, top token = ' of', max act = 1.381
# Feature 28 — top 5 activating tokens:
#
#   1.381  token=          ' of'   context: On August 22, 2015, at approximately 07:13 a.m., the Coos Bay Police Department
#   1.370  token=          ' of'   context: The Justice Department will monitor the investigation into the controversial sho
#   1.366  token=          ' of'   context: The blast, which also wounded 17, occurred when the bombmakers were unloading th
#   1.366  token=          ' of'   context: Please turn on JavaScript. Media requires JavaScript to play. The remains of 534
#   1.362  token=          ' of'   context: A former Arizona police officer was found not guilty of murder Thursday of in th
#
# Feature 31: 100% consistent, top token = ' domestic', max act = 1.818
# Feature 31 — top 5 activating tokens:
#
#   1.818  token=    ' domestic'   context: Jackie Calmes, NYT: At 10 percent of the gross domestic product, the 2009 defici
#   1.766  token=    ' domestic'   context: Cook County Sheriff's Department Elaine Cook, 51, was charged with aggravated do
#   1.740  token=    ' domestic'   context: IQ and the Wealth of Nations is a 2002 book by psychologist Richard Lynn and pol
#   1.704  token=    ' domestic'   context: In my mental cabinet of things available to recite on cue, I would like to have
#   1.682  token=    ' domestic'   context: There are movies, and then there is real life.
#
# Global military spending rose to
#
# Feature 32: 100% consistent, top token = ' up', max act = 2.499
# Feature 32 — top 5 activating tokens:
#
#   2.499  token=          ' up'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#   2.499  token=          ' up'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#   2.499  token=          ' up'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#   2.499  token=          ' up'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#   2.499  token=          ' up'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#
# Feature 39: 100% consistent, top token = ' enough', max act = 4.049
# Feature 39 — top 5 activating tokens:
#
#   4.049  token=      ' enough'   context: Author: Marshall Schott
#
# After my post on BIAB a few weeks ago, I received comme
#   4.021  token=      ' enough'   context: Will the end of the Kansas tax-cut experiment — hey, that’s what Brownback himse
#   4.000  token=      ' enough'   context: This looks like the group the Dolphins are sticking with for the next few season
#   3.985  token=      ' enough'   context: If you ever wanted proof that soccer was a game of two halves, look no further t
#   3.977  token=      ' enough'   context: Welcome to a new project, experiment, challenge or whatever you wanna call it. N
#
# Feature 49: 100% consistent, top token = ' bi', max act = 2.412
# Feature 49 — top 5 activating tokens:
#
#   2.412  token=          ' bi'   context: Erasmus Darwin, (born Dec. 12, 1731, Elston Hall, Nottinghamshire, Eng.—died Apr
#   2.349  token=          ' bi'   context: T he psychological analysis and personality profile that follows below will exte
#   2.330  token=          ' bi'   context: The Washington Nationals got to celebrate a no-hitter Sunday, and Thomas Boswell
#   2.307  token=          ' bi'   context: Ubisoft Motion Pictures, the film and television studio of the Ubisoft game publ
#   2.293  token=          ' bi'   context: Paul Kranz, Paula Broadwell’s father, defends his daughter and claims her affair
#
# Feature 62: 100% consistent, top token = ' K', max act = 3.190
# Feature 62 — top 5 activating tokens:
#
#   3.190  token=           ' K'   context: WASHINGTON (AP) — The federal government is asking a judge to put on hold a requ
#   3.159  token=           ' K'   context: How important is reading fiction in socializing school children? Researchers at
#   3.148  token=           ' K'   context: Robert Post, left, and his wife, Jane Post, center, talk to neighbor Gail Kender
#   3.136  token=           ' K'   context: You may want to soak your brown rice.
#
# Researchers have found that a compound th
#   3.118  token=           ' K'   context: Deputy editorial page editor
#
# Of the deluge of sexual-harassment stories gushing
#
# Feature 65: 100% consistent, top token = ' local', max act = 4.007
# Feature 65 — top 5 activating tokens:
#
#   4.007  token=       ' local'   context: Former TD Conor Lenihan is considering standing for Fianna Fáil in the next gene
#   3.935  token=       ' local'   context: First of all we would like to thank everyone who donated to our first kickstarte
#   3.922  token=       ' local'   context: The southbound northbound Muni shelter at 18th & Church streets, just outside Do
#   3.920  token=       ' local'   context: The Maltese public has outdone itself on the generosity front with an unbelievab
#   3.913  token=       ' local'   context: Daniel Rom Kristiansen uncovered the wreckage - as well as the remains of the pi
#
# Feature 68: 100% consistent, top token = ' President', max act = 4.867
# Feature 68 — top 5 activating tokens:
#
#   4.867  token=   ' President'   context: Breaking News Emails Get breaking news alerts and special reports. The news and
#   4.808  token=   ' President'   context: The White House is barring counselor Kellyanne Conway from television appearance
#   4.757  token=   ' President'   context: New revenue must be part of any bipartisan agreement to eliminate the sequester,
#   4.706  token=   ' President'   context: Mayor Michael Hancock on Thursday said Denver would do what it could to uphold t
#   4.706  token=   ' President'   context: “I think we’re in impeachment territory.”
#
# Those were not the words of a left-wi
#
# Feature 75: 100% consistent, top token = '..', max act = 5.993
# Feature 75 — top 5 activating tokens:
#
#   5.993  token=           '..'   context: .......... .......... .......... .......... .......... .......... .......... ...
#   5.993  token=           '..'   context: .......... .......... .......... .......... .......... .......... .......... ...
#   5.993  token=           '..'   context: .......... .......... .......... .......... .......... .......... .......... ...
#   5.993  token=           '..'   context: .......... .......... .......... .......... .......... .......... .......... ...
#   5.992  token=           '..'   context: .......... .......... .......... .......... .......... .......... .......... ...
#
# Feature 76: 100% consistent, top token = 'C', max act = 1.979
# Feature 76 — top 5 activating tokens:
#
#   1.979  token=            'C'   context: This is great stuff. Watch Texas Sen. Ted Cruz explain to an extremely rude NBC
#   1.907  token=            'C'   context: Outspoken billionaire Mark Cuban has a bone to pick with the US Securities and E
#   1.905  token=            'C'   context: Mark Cuban bet on the wrong horse and now he’s out in the wilderness, or maybe n
#   1.897  token=            'C'   context: Ted Cruz has been rolling up delegates and positions on powerful rules committee
#   1.859  token=            'C'   context: Ted Cruz makes a speech at a campaign rally on March 5 in Wichita, Kansas. J Pat
#
# Feature 77: 100% consistent, top token = ' pre', max act = 5.986
# Feature 77 — top 5 activating tokens:
#
#   5.986  token=         ' pre'   context: And we return to the adventures of Daring Do!
#
# "Origin Story" was originally con
#   5.962  token=         ' pre'   context: 15User Rating: 1 out of 5
#
# Review title of FEARtheNOISE300 DO NOT BUY, IT'S JUST
#   5.910  token=         ' pre'   context: Last week the Kingdom Hearts II Organization XIII Roxas Play Arts Kai figurine r
#   5.902  token=         ' pre'   context: It’s Sunday morning a few weeks before Christmas and the ice is flowing at North
#   5.897  token=         ' pre'   context: "The meaner Regina was to her, the more Gretchen tried to win Regina back. She k
#
# Feature 79: 100% consistent, top token = ' some', max act = 3.163
# Feature 79 — top 5 activating tokens:
#
#   3.163  token=        ' some'   context: The U.S. Bureau of Alcohol, Tobacco, Firearms and Explosives classifies the SKS
#   3.112  token=        ' some'   context: A year ago, Tammy Rose never imagined she’d be active again in church, holding a
#   3.104  token=        ' some'   context: Most of us use services like Gmail, Feedly, and Instapaper to get through the da
#   3.102  token=        ' some'   context: Unlike Alien vs. Predator, which sated fans with tons of tie-in merchandise duri
#   3.078  token=        ' some'   context: The “Bernie or Bust” contingent is growing as the divide between Hillary Clinton
#
# Feature 81: 100% consistent, top token = ' career', max act = 2.856
# Feature 81 — top 5 activating tokens:
#
#   2.856  token=      ' career'   context: In 2014, the Dallas Cowboys boasted one of the best offenses in football. Built
#   2.835  token=      ' career'   context: Dallas Stars General Manager Jim Nill announced today that the club has signed d
#   2.806  token=      ' career'   context: Jrue Holiday had been steadily improving since his rookie season, until the star
#   2.795  token=      ' career'   context: The Lehigh Valley Phantoms have re-signed forward Chris Conner to a two-year dea
#   2.782  token=      ' career'   context: ← Sidebar
#
# At the 2013 US Open I asked Pancho Segura for his thoughts on then 22
#
# Feature 83: 100% consistent, top token = ' ’', max act = 2.015
# Feature 83 — top 5 activating tokens:
#
#   2.015  token=           ' ’'   context: What’s really going up in there in the skies?
#
# History recently gave a 10-episod
#   2.010  token=           ' ’'   context: Week 12: Country Woman
#
# Will Batts
#
# The Man
#
# Will Batts was a fiddler who was pa
#   2.005  token=           ' ’'   context: According to Guy Voglino, the Brooks Brothers vice president charged with managi
#   1.983  token=           ' ’'   context: Right-hand drive, 800hp ’Cuda from Schwartz Performance
#
# Mopar’s designers and e
#   1.973  token=           ' ’'   context: The Beatles were sex machines in their early days on the road – sleeping nightly
#
# Feature 85: 100% consistent, top token = ' will', max act = 1.583
# Feature 85 — top 5 activating tokens:
#
#   1.583  token=        ' will'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#   1.583  token=        ' will'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#   1.583  token=        ' will'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#   1.583  token=        ' will'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#   1.583  token=        ' will'   context: Ready to fight back? Sign up for Take Action Now and get three actions in your i
#
# Feature 87: 100% consistent, top token = ' cr', max act = 4.007
# Feature 87 — top 5 activating tokens:
#
#   4.007  token=          ' cr'   context: When Ari Emanuel, the 53-year-old co-C.E.O. of the powerhouse talent agency Will
#   4.000  token=          ' cr'   context: A switch machine was so badly damaged in Monday's derailment in Penn Station tha
#   3.983  token=          ' cr'   context: The Huffington Post sent a list of questions on criminal justice to all of the m
#   3.983  token=          ' cr'   context: “Orban has talked about the Trump era being a new international opportunity for
#   3.981  token=          ' cr'   context: 6 absurd right-wing lies about food stamps Perhaps the biggest myth? The financi
#
# Feature 88: 100% consistent, top token = ' for', max act = 3.025
# Feature 88 — top 5 activating tokens:
#
#   3.025  token=         ' for'   context: Started this when i was bored one night (Although thats pretty much every night)
#   2.805  token=         ' for'   context: Hi, Jose.
#
# Thanks for the interview. I know this is a tough time for you. So, yo
#   2.802  token=         ' for'   context: Railgan Profile Joined August 2010 Switzerland 1472 Posts Last Edited: 2016-09-2
#   2.778  token=         ' for'   context: Thanks for visiting my Kickstarter funding page! I hope you enjoy the project id
#   2.778  token=         ' for'   context: Thanks for the brake down but really this is not the first such pack like this t

# %% [markdown]
# # W_dec Cosine Similarity Analysis

# %%
import numpy as np

# Normalize decoder weights
W_dec = sae.W_dec.data.clone()  # (m, d)
W_dec_normed = W_dec / W_dec.norm(dim=1, keepdim=True)

# Compute stats via chunked matmul — never allocate the full (m, m) matrix
CHUNK = 1024
max_sim = -1.0
sim_sum = 0.0

for i in range(0, m, CHUNK):
    chunk = W_dec_normed[i:i+CHUNK] @ W_dec_normed.T  # (CHUNK, m)
    # Zero out self-similarities
    for k in range(chunk.shape[0]):
        chunk[k, i + k] = 0.0
    max_sim = max(max_sim, chunk.max().item())
    sim_sum += chunk.sum().item()

print(f"Decoder weight matrix: {W_dec.shape}")
print(f"Max off-diagonal similarity: {max_sim:.4f}")
print(f"Mean off-diagonal similarity: {sim_sum / (m * (m - 1)):.4f}")
# Out:
# Decoder weight matrix: torch.Size([4096, 512])
# Max off-diagonal similarity: 0.8024
# Mean off-diagonal similarity: 0.0015

# %%
# Build histogram from chunks — never allocate full upper triangle
CHUNK = 1024
bins = np.linspace(-1, 1, 201)
hist_counts = np.zeros(len(bins) - 1, dtype=np.int64)
count_05 = 0
count_07 = 0
count_09 = 0

for i in range(0, m, CHUNK):
    chunk = W_dec_normed[i:i+CHUNK] @ W_dec_normed.T  # (CHUNK, m)
    # Only take upper triangle contributions: pairs (i+k, j) where j > i+k
    for k in range(chunk.shape[0]):
        row = chunk[k, i+k+1:].numpy()  # only j > i+k
        if len(row) == 0:
            continue
        hist_counts += np.histogram(row, bins=bins)[0]
        abs_row = np.abs(row)
        count_05 += (abs_row > 0.5).sum()
        count_07 += (abs_row > 0.7).sum()
        count_09 += (abs_row > 0.9).sum()

plt.figure(figsize=(10, 5))
plt.bar(bins[:-1], hist_counts, width=np.diff(bins), align='edge', alpha=0.8)
plt.xlabel("Cosine Similarity")
plt.ylabel("Count")
plt.title("Distribution of Pairwise Decoder Vector Cosine Similarities")
plt.axvline(x=0, color='gray', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

print(f"Pairs with |cos_sim| > 0.5: {count_05}")
print(f"Pairs with |cos_sim| > 0.7: {count_07}")
print(f"Pairs with |cos_sim| > 0.9: {count_09}")
# Out:
# Pairs with |cos_sim| > 0.5: 3305
# Pairs with |cos_sim| > 0.7: 748
# Pairs with |cos_sim| > 0.9: 258

# %%
# Find top similar pairs using chunked topk — no full matrix sort
N_PAIRS = 20
TOP_PER_CHUNK = 200  # keep extra candidates for filtering

def top_token(feat_idx):
    idx = top_idxs[feat_idx, 0].item()
    return all_tokens[idx].strip() if idx >= 0 else ""

# Gather candidate pairs from chunks
CHUNK = 1024
candidates = []  # list of (sim_val, i, j)

for i in range(0, m, CHUNK):
    chunk = W_dec_normed[i:i+CHUNK] @ W_dec_normed.T  # (CHUNK, m)
    # Zero out self-similarities and lower triangle (avoid duplicates)
    for k in range(chunk.shape[0]):
        chunk[k, :i+k+1] = 0.0
    # Get top similarities from this chunk
    vals, idxs = chunk.flatten().topk(min(TOP_PER_CHUNK, chunk.numel()))
    for v, flat_idx in zip(vals, idxs):
        row = flat_idx.item() // m
        col = flat_idx.item() % m
        candidates.append((v.item(), i + row, col))

# Sort all candidates and display
candidates.sort(key=lambda x: -x[0])

print(f"Top {N_PAIRS} most similar feature pairs (filtered to meaningful tokens):\n")
seen = set()
count = 0
for sim_val, i, j in candidates:
    if count >= N_PAIRS:
        break
    pair = (min(i, j), max(i, j))
    if pair in seen:
        continue
    seen.add(pair)
    tok_i, tok_j = top_token(i), top_token(j)
    if len(tok_i) <= 1 or len(tok_j) <= 1:
        continue
    print(f"Features {i} & {j}: cosine sim = {sim_val:.4f}")
    inspect_feature(i, k=3)
    inspect_feature(j, k=3)
    print("-" * 80)
    count += 1
# Out:
# Top 20 most similar feature pairs (filtered to meaningful tokens):
#
# Features 3041 & 3961: cosine sim = 0.7074
# Feature 3041 — top 3 activating tokens:
#
#   6.853  token=         ' may'   context: Dragon's Dogma
#
# Capcom
#
# Rated By Our Customers Compatible with PlayStation 3™ (P
#   6.819  token=        ' will'   context: About
#
# So please, support us TODAY and be part of the Holiplay experience where
#   6.657  token=        ' will'   context: This is a design for a hotel room with a king-size bed at the Old Post Office bu
# Feature 3961 — top 3 activating tokens:
#
#   5.334  token=           '10'   context: Blog Archive Mar 2018 (2) Feb 2018 (5) Jan 2018 (9) Dec 2017 (1) Apr 2017 (4) Ma
#   5.117  token=         'uchi'   context: Jones
#
# vs.
#
# Cormier Cerrone
#
# vs.
#
# Jury Tavares
#
# vs.
#
# Marquardt Horiguchi
#
# vs.
#
# G
#   4.915  token=            '3'   context: July (1) January (1) November (1) September (2) June (1) March (1) January (1) N
# --------------------------------------------------------------------------------
# Features 302 & 3845: cosine sim = 0.6878
# Feature 302 — top 3 activating tokens:
#
#   4.215  token=          'ail'   context: Date Name(s) Location Insignia Notes
#
# 19 AUG 18 CW3 Taylor J. Galvin [P] Iraq D/
#   4.179  token=         ' new'   context: The United Nations formally endorsed and approved numerous anti-Israel and anti-
#   4.150  token=          'For'   context: Equality Texas gears up for the prolonged fight against bathroom bill
#
# Marceline
# Feature 3845 — top 3 activating tokens:
#
#   5.352  token=           '10'   context: Blog Archive Mar 2018 (2) Feb 2018 (5) Jan 2018 (9) Dec 2017 (1) Apr 2017 (4) Ma
#   5.135  token=           '10'   context: Blog Archive Mar 2018 (2) Feb 2018 (5) Jan 2018 (9) Dec 2017 (1) Apr 2017 (4) Ma
#   5.122  token=            '�'   context: This video is no longer available
#
# This video was hosted on Vidme, which is no l
# --------------------------------------------------------------------------------
# Features 1122 & 2062: cosine sim = 0.6780
# Feature 1122 — top 3 activating tokens:
#
#   4.322  token=          ' it'   context: Four days before it was scheduled to be turned off, YouTube has been deactivated
#   4.311  token=          ' it'   context: We’ll believe it when we see it.
#
# Jay Electronica has been more of a tabloid sta
#   4.280  token=          ' it'   context: This was a homework assignment for art class.
#
# The theme was "pears/pairs" and t
# Feature 2062 — top 3 activating tokens:
#
#   6.519  token=           'It'   context: NOBEL-winning economist Joseph Stiglitz has described the Irish ability to suck
#   6.471  token=           'It'   context: The new Chinese commerce minister would soon sign a set of guidelines that would
#   6.460  token=           'It'   context: Turing Pharmaceuticals CEO Martin Shkreli (CBS/screen grab)
#
# Turing Pharmaceutic
# --------------------------------------------------------------------------------
# Features 106 & 2044: cosine sim = 0.6754
# Feature 106 — top 3 activating tokens:
#
#   5.309  token=         ' has'   context: Gambia has executed nine death row prisoners, after President Yahya Jammeh vowed
#   5.203  token=         ' has'   context: Far-right protesters rally in the town of Dover in southeast England on May 28.
#   5.117  token=         ' has'   context: A European Union without the United Kingdom: The Geopolitics of a British Exit f
# Feature 2044 — top 3 activating tokens:
#
#   4.312  token=         ' had'   context: Media playback is not supported on this device MOTD's Gary Lineker on pants and
#   4.302  token=         ' had'   context: A Prince George, B.C., man says he's 'totally stoked' to be alive after being st
#   4.285  token=         ' had'   context: The Associated Press
#
# TAMPA, Fla. -- Former pro wrestler Hulk Hogan sued a disc
# --------------------------------------------------------------------------------
# Features 1082 & 3961: cosine sim = 0.6673
# Feature 1082 — top 3 activating tokens:
#
#   4.606  token=       ' Black'   context: Disposable Income Clothing
#
# "Free Ghost" Men's T-Shirt
#
# $ 29.99 White / XS - $ 2
#   4.559  token=           'AB'   context: Extreme Approaches Quiz
#
# — New batch of questions every time —
#
# 1. Lukla, Nepal
#   4.510  token=           'AB'   context: Extreme Approaches Quiz
#
# — New batch of questions every time —
#
# 1. Lukla, Nepal
# Feature 3961 — top 3 activating tokens:
#
#   5.334  token=           '10'   context: Blog Archive Mar 2018 (2) Feb 2018 (5) Jan 2018 (9) Dec 2017 (1) Apr 2017 (4) Ma
#   5.117  token=         'uchi'   context: Jones
#
# vs.
#
# Cormier Cerrone
#
# vs.
#
# Jury Tavares
#
# vs.
#
# Marquardt Horiguchi
#
# vs.
#
# G
#   4.915  token=            '3'   context: July (1) January (1) November (1) September (2) June (1) March (1) January (1) N
# --------------------------------------------------------------------------------
# Features 302 & 3961: cosine sim = 0.6558
# Feature 302 — top 3 activating tokens:
#
#   4.215  token=          'ail'   context: Date Name(s) Location Insignia Notes
#
# 19 AUG 18 CW3 Taylor J. Galvin [P] Iraq D/
#   4.179  token=         ' new'   context: The United Nations formally endorsed and approved numerous anti-Israel and anti-
#   4.150  token=          'For'   context: Equality Texas gears up for the prolonged fight against bathroom bill
#
# Marceline
# Feature 3961 — top 3 activating tokens:
#
#   5.334  token=           '10'   context: Blog Archive Mar 2018 (2) Feb 2018 (5) Jan 2018 (9) Dec 2017 (1) Apr 2017 (4) Ma
#   5.117  token=         'uchi'   context: Jones
#
# vs.
#
# Cormier Cerrone
#
# vs.
#
# Jury Tavares
#
# vs.
#
# Marquardt Horiguchi
#
# vs.
#
# G
#   4.915  token=            '3'   context: July (1) January (1) November (1) September (2) June (1) March (1) January (1) N
# --------------------------------------------------------------------------------
# Features 901 & 1078: cosine sim = 0.6382
# Feature 901 — top 3 activating tokens:
#
#   3.882  token=          ' 66'   context: Published: March 21, 2017
#
# ISLAMABAD: The strong resolve of the ruling Pakistan
#   3.873  token=          ' 62'   context: "Janet, we have a problem," is the resoundingly loud message from the latest Gal
#   3.734  token=          ' 66'   context: Polltakers for the General Social Survey, done by NORC at the University of Chic
# Feature 1078 — top 3 activating tokens:
#
#   3.767  token=          ' 17'   context: The Gaia torus is complete
#
# 28 July 2009
#
# The 3-metre diameter, quasi-octagonal
#   3.751  token=          ' 16'   context: Suicide Most Likely on Mondays, According to UK Study
#
# by Kevin Caruso
#
# August 2
#   3.712  token=          ' 16'   context: This mod is an addon to the Chisels & Bits mod. It adds a wrench that rotates/mi
# --------------------------------------------------------------------------------
# Features 341 & 2586: cosine sim = 0.6301
# Feature 341 — top 3 activating tokens:
#
#   5.643  token=         ' The'   context: PANAMA CITY, Oct 22 (Reuters) - Panama has banned entry of travelers from Liberi
#   5.475  token=         ' The'   context: With colleges under growing pressure to reduce alcohol-soaked student misbehavio
#   5.469  token=         ' The'   context: "Famine-like conditions" have been detected in areas of Yemen, although an offic
# Feature 2586 — top 3 activating tokens:
#
#   3.990  token=         ' the'   context: A look around at the reactions to today's administration announcement of new reg
#   3.927  token=         ' the'   context: In macroeconomic models, if everything works perfectly -- if all markets clear a
#   3.917  token=         ' the'   context: Enlarge Image Joe Raedle/Getty Images
#
# Silicon Valley investor Peter Thiel is a
# --------------------------------------------------------------------------------
# Features 1660 & 3428: cosine sim = 0.6291
# Feature 1660 — top 3 activating tokens:
#
#   4.286  token=          ' be'   context: With YouTube’s brand redesign in August, Google’s video service significantly re
#   4.107  token=          ' be'   context: Today’s Christmas day and I feel like winter hasn’t even started — Me: damn bros
#   4.032  token=          ' be'   context: Ryan Adams has announced a new album, Prisoner. It’s out February 17 via Pax Am/
# Feature 3428 — top 3 activating tokens:
#
#   4.402  token=          ' be'   context: As mentioned, the ever-influential Kinsella family are reviving their Owls proje
#   4.391  token=          ' be'   context: The new Global Brand Ambassador of Revlon spills the beans on her beauty must-ha
#   4.367  token=          ' be'   context: Organizers of an upcoming Italian-Canadian celebration to mark Canada's 150th bi
# --------------------------------------------------------------------------------
# Features 3600 & 4045: cosine sim = 0.6232
# Feature 3600 — top 3 activating tokens:
#
#   3.066  token=       ' think'   context: Getty Images
#
# Tim Tebow might not be done playing professional football.
#
# Tebow,
#   3.022  token=           ' I'   context: EL SEGUNDO, Calif. -- It was four days in a season that at times has felt four y
#   2.992  token=       ' think'   context: PHILADELPHIA ― The chairman of Hillary Clinton’s campaign urged U.S. intelligenc
# Feature 4045 — top 3 activating tokens:
#
#   2.423  token=        'assis'   context: Product information:
#
# QBX Mini-ITX Cube Chassis - Black
#
# Features
#
# Specification
#   2.343  token=       ' sense'   context: "It would not make sense for us to see a top priority as going after recreationa
#   2.339  token=        ' year'   context: "Apple hasn't been up to its normal brilliant performance for much of the past y
# --------------------------------------------------------------------------------
# Features 3600 & 3620: cosine sim = 0.6231
# Feature 3600 — top 3 activating tokens:
#
#   3.066  token=       ' think'   context: Getty Images
#
# Tim Tebow might not be done playing professional football.
#
# Tebow,
#   3.022  token=           ' I'   context: EL SEGUNDO, Calif. -- It was four days in a season that at times has felt four y
#   2.992  token=       ' think'   context: PHILADELPHIA ― The chairman of Hillary Clinton’s campaign urged U.S. intelligenc
# Feature 3620 — top 3 activating tokens:
#
#   2.556  token=   ' forbidden'   context: A swimming pool in Austria has had to put up signs warning male migrants not to
#   2.536  token=      ' guests'   context: A swimming pool in Austria has had to put up signs warning male migrants not to
#   2.480  token=        ' shot'   context: Woodley went on MMAJunkie Radio to express his feelings about the announcement,
# --------------------------------------------------------------------------------
# Features 1401 & 2509: cosine sim = 0.6207
# Feature 1401 — top 3 activating tokens:
#
#   3.356  token=      ' steady'   context: World of Warcraft will be reaching a significant milestone with their 10 year an
#   3.315  token=       ' heavy'   context: JABALYA, GAZA STRIP—The Balatas, like many Palestinian families, disliked Israel
#   3.160  token=      ' steady'   context: Paul Scholes insists Jose Mourinho should partner Paul Pogba with Michael Carric
# Feature 2509 — top 3 activating tokens:
#
#   3.153  token=     ' Service'   context: Police questioned two people at a North Columbus motel Thursday night about a sh
#   3.094  token=          ' GH'   context: Abstract Although both growth hormone (GH) and insulin-like growth factor 1 (IGF
#   2.996  token=            'a'   context: Looking for news you can trust?
#
# Subscribe to our free newsletters.
#
# This story
# --------------------------------------------------------------------------------
# Features 587 & 2106: cosine sim = 0.6179
# Feature 587 — top 3 activating tokens:
#
#   6.320  token=        ' that'   context: A woman takes a photograph of her husband in front of part of the Berlin Wall at
#   6.310  token=        ' that'   context: Part Two looks at some more complex animations like simple transitions and anima
#   6.271  token=        ' that'   context: Anti-Trump Republicans will make their final stand this week, a long-shot bid to
# Feature 2106 — top 3 activating tokens:
#
#   6.035  token=       ' which'   context: Rep. Jared Polis (D-CO), one of the few openly gay members of Congress, blasted
#   6.021  token=       ' which'   context: Newly released data from the Ontario government shows half of real estate transa
#   5.970  token=       ' which'   context: The House of Representatives today is expected to vote on the American Health Ca
# --------------------------------------------------------------------------------
# Features 1109 & 3912: cosine sim = 0.6157
# Feature 1109 — top 3 activating tokens:
#
#   5.835  token=         ' the'   context: CNN Erin Burnett and Kellyanne Conway -- (CNN screen grab)
#
# Appearing on CNN wit
#   5.731  token=         ' the'   context: Christine O’Donnell: She might be the GOP establishment’s new BFF.
#
# Yes, Best Fr
#   5.717  token=         ' the'   context: One of the more memorable stories this season was the Dogecoin and Reddit commun
# Feature 3912 — top 3 activating tokens:
#
#   5.339  token=         ' the'   context: Top 14
#
# Wilkinson refuses to rule out new deal
#
# ESPN Staff
#
# The Top 14 captains
#   5.325  token=         ' the'   context: Back in March 2017, the YouTube channel known as SourceFed came to an end shortl
#   5.222  token=         ' the'   context: Share. “In success, I think all those things would be possible." “In success, I
# --------------------------------------------------------------------------------
# Features 827 & 1754: cosine sim = 0.6133
# Feature 827 — top 3 activating tokens:
#
#   3.417  token=      ' emails'   context: WikiLeaks has published 294,546 emails along with thousands of attached files fr
#   3.417  token=     ' grooves'   context: The gifted guitarist, singer and songwriter Jeff Buckley would have turned 45 ye
#   3.382  token=       ' roads'   context: https://iwandered.net/temples-of-mrauk-u-burma-myanmar/
#
# The alarm rang. At 5:30
# Feature 1754 — top 3 activating tokens:
#
#   2.239  token=           'ds'   context: A Broadway actress has taken the rare step of publicly challenging the tone of a
#   2.109  token=           'ds'   context: Despite its ominously evocative title, HBO’s Beware the Slenderman is not a horr
#   2.087  token=           'ds'   context: It is appalling that in 2017 we still need to have a conversation about sexual c
# --------------------------------------------------------------------------------
# Features 293 & 2586: cosine sim = 0.6102
# Feature 293 — top 3 activating tokens:
#
#   4.538  token=         ' the'   context: We’ve turned a horrible new page in the War on Terror as the FDNY — The Fire Dep
#   4.481  token=         ' the'   context: Mr Erdogan said the sight of American flags in the convoy alongside YPG insignia
#   4.476  token=         ' the'   context: If you're a gamer, or even if you've just been around certain parts of the Inter
# Feature 2586 — top 3 activating tokens:
#
#   3.990  token=         ' the'   context: A look around at the reactions to today's administration announcement of new reg
#   3.927  token=         ' the'   context: In macroeconomic models, if everything works perfectly -- if all markets clear a
#   3.917  token=         ' the'   context: Enlarge Image Joe Raedle/Getty Images
#
# Silicon Valley investor Peter Thiel is a
# --------------------------------------------------------------------------------
# Features 1230 & 3427: cosine sim = 0.6101
# Feature 1230 — top 3 activating tokens:
#
#   4.458  token=       ' could'   context: WASHINGTON (Reuters) - Ten months after the botched rollout of HealthCare.gov, O
#   4.445  token=       ' could'   context: India's Central Bank Governor Raghuram Rajan has cautioned that robots are repla
#   4.412  token=       ' could'   context: By Annabel Symington
#
# ISLAMABAD – In what has been widely perceived as a pre-ele
# Feature 3427 — top 3 activating tokens:
#
#   5.765  token=       ' would'   context: EA's like-it-or-lump-it Origin service has divided gamers who either like it, or
#   5.662  token=       ' would'   context: University of Iowa President Sally Mason made some comments to a student newspap
#   5.644  token=       ' would'   context: Count Alexander Shlemenko among those who would like to see Bellator adopt five-
# --------------------------------------------------------------------------------
# Features 3546 & 3912: cosine sim = 0.6096
# Feature 3546 — top 3 activating tokens:
#
#   2.470  token=         ' the'   context: Cathy Heller became the ninth woman to allege Trump acted inappropriately toward
#   2.454  token=         ' the'   context: Cathy Heller became the ninth woman to allege Trump acted inappropriately toward
#   2.450  token=         ' the'   context: A man who witnessed the ‘encounter’ where an Edmonton police officer shot and ki
# Feature 3912 — top 3 activating tokens:
#
#   5.339  token=         ' the'   context: Top 14
#
# Wilkinson refuses to rule out new deal
#
# ESPN Staff
#
# The Top 14 captains
#   5.325  token=         ' the'   context: Back in March 2017, the YouTube channel known as SourceFed came to an end shortl
#   5.222  token=         ' the'   context: Share. “In success, I think all those things would be possible." “In success, I
# --------------------------------------------------------------------------------
# Features 341 & 2501: cosine sim = 0.6091
# Feature 341 — top 3 activating tokens:
#
#   5.643  token=         ' The'   context: PANAMA CITY, Oct 22 (Reuters) - Panama has banned entry of travelers from Liberi
#   5.475  token=         ' The'   context: With colleges under growing pressure to reduce alcohol-soaked student misbehavio
#   5.469  token=         ' The'   context: "Famine-like conditions" have been detected in areas of Yemen, although an offic
# Feature 2501 — top 3 activating tokens:
#
#   3.043  token=          'The'   context: Students work on a practice ACT test in this 2011 file photo. (AP Photo/The Enqu
#   3.008  token=          'The'   context: Primary Overview
#
# The Alabama special election to fill the Senate seat left vaca
#   2.997  token=          'The'   context: Jim Green, head of NASA's planetary science division, answers your questions abo
# --------------------------------------------------------------------------------
# Features 973 & 1091: cosine sim = 0.6086
# Feature 973 — top 3 activating tokens:
#
#   5.831  token=         ' two'   context: The Government has collected almost €3bn more in taxes than it expected to, acco
#   5.786  token=         ' two'   context: The appetite of American Horror Story has grown from year to year in terms of ra
#   5.782  token=         ' two'   context: Source: Xinhua| 2017-04-07 18:34:01|Editor: Tian Shaohui
#
# Video Player Close
#
# BE
# Feature 1091 — top 3 activating tokens:
#
#   3.234  token=        'eight'   context: Ahead of England's World Cup qualifier against Poland, former Juventus player an
#   3.146  token=       ' eight'   context: In June of 77, just after Elvis’s last concert and just before his death in Augu
#   3.119  token=       ' eight'   context: Forty years ago today, two Americans touched down on the moon and walked upon it
# --------------------------------------------------------------------------------

# %%
# Cluster decoder vectors using KMeans (scales to any m, unlike hierarchical linkage)
from sklearn.cluster import MiniBatchKMeans
from scipy.cluster.hierarchy import linkage, dendrogram

N_CLUSTERS = 50
kmeans = MiniBatchKMeans(n_clusters=N_CLUSTERS, batch_size=1024, random_state=42)
labels = kmeans.fit_predict(W_dec_normed.numpy())

# Show cluster sizes
cluster_sizes = np.bincount(labels, minlength=N_CLUSTERS)
print(f"Cluster sizes: min={cluster_sizes.min()}, max={cluster_sizes.max()}, "
      f"median={np.median(cluster_sizes):.0f}")

# Hierarchical clustering of the 50 cluster centroids (cheap: only 50x50)
centroids = kmeans.cluster_centers_
centroids_normed = centroids / np.linalg.norm(centroids, axis=1, keepdims=True)
centroid_cos_dist = 1 - centroids_normed @ centroids_normed.T
np.fill_diagonal(centroid_cos_dist, 0)
centroid_cos_dist = np.clip(centroid_cos_dist, 0, 2)

from scipy.spatial.distance import squareform
condensed = squareform(centroid_cos_dist)
Z = linkage(condensed, method='ward')

plt.figure(figsize=(14, 6))
dendrogram(Z, leaf_rotation=90, leaf_font_size=8,
           labels=[f"C{i} ({cluster_sizes[i]})" for i in range(N_CLUSTERS)])
plt.title(f"Hierarchical Clustering of {N_CLUSTERS} KMeans Cluster Centroids")
plt.xlabel("Cluster (size)")
plt.ylabel("Ward Distance")
plt.tight_layout()
plt.show()

# %%
def search_token(query, k=5):
    """Find features whose top-K activating tokens match the query.
    
    Matches any token containing the query string (case-insensitive).
    """
    results = []
    for feat_idx in range(m):
        idxs = top_idxs[feat_idx]
        valid = idxs[idxs >= 0]
        for rank, tok_idx in enumerate(valid[:K]):
            tok = all_tokens[tok_idx.item()]
            if query.lower() in tok.lower():
                results.append((feat_idx, rank, top_vals[feat_idx, rank].item(), tok))
                break  # only count best rank per feature

    results.sort(key=lambda x: x[1])  # sort by rank (0 = top token)
    print(f"Features with '{query}' in top-{K} tokens: {len(results)}\n")
    for feat_idx, rank, val, tok in results[:20]:
        print(f"  Feature {feat_idx}: rank={rank}, activation={val:.3f}, token={repr(tok)}")
    return results

# Example usage:
search_token("Houston")
print()
# Out:
# Features with 'Houston' in top-20 tokens: 11
#
#   Feature 2301: rank=1, activation=0.235, token=' Houston'
#   Feature 13945: rank=1, activation=0.271, token=' Houston'
#   Feature 10272: rank=5, activation=0.262, token=' Houston'
#   Feature 10679: rank=5, activation=0.294, token=' Houston'
#   Feature 3749: rank=6, activation=0.235, token=' Houston'
#   Feature 15639: rank=8, activation=1.318, token=' Houston'
#   Feature 5169: rank=11, activation=0.255, token=' Houston'
#   Feature 6667: rank=11, activation=0.303, token=' Houston'
#   Feature 1379: rank=15, activation=0.580, token=' Houston'
#   Feature 7760: rank=16, activation=0.205, token=' Houston'
#   Feature 10931: rank=16, activation=0.837, token=' Houston'

# %%
inspect_feature(2000, k=5)
# Out:
# Feature 2000 — top 5 activating tokens:
#
#   8.424  token=          ' un'   context: Hey guys, Welcome to the Official IW Avatar Design Contest!
#
# How does it work?
#
#
#   8.384  token=          ' un'   context: The man who wished to be eaten seemed quite shy when he walked into a Toronto ps
#   8.358  token=          ' un'   context: If you're waiting for someone who has to drive in San Francisco, especially arou
#   8.330  token=          ' un'   context: Two aspiring rappers from the rough streets of Washington, D.C. and its outer re
#   8.326  token=          ' un'   context: First edition (UK)
#
# The Incredible Journey (1961), by Scottish author Sheila Bur

# %%
inspect_feature(3244, k=5)
# Out:
# Feature 3244 — top 5 activating tokens:
#
#   8.285  token=          ' re'   context: As part of our collaboration with Elizabeth St gallery, FLINT is curating the wo
#   8.247  token=          ' re'   context: In the first instalment of a series on the threat of water scarcity, Pilita Clar
#   8.240  token=          ' re'   context: Fearing Death and Curing Aging
#
# You are going to die. It may take some time, but
#   8.164  token=          ' re'   context: UPDATE 2
#
# May 13, 2016
#
# Seed of Life is a meditative game in which you deflect c
#   8.145  token=          ' re'   context: “NO ONE,” the coach says to a locker room full of determined-looking young Ameri
