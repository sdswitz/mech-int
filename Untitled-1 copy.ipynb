# %%
import torch

# %%
import transformer_lens

# Load a model (eg GPT-2 Small)
# model = transformer_lens.HookedTransformer.from_pretrained("pythia-70m")
model = transformer_lens.HookedTransformer.from_pretrained("gpt2-small")

# Run the model and get logits and activations
logits, activations = model.run_with_cache("Hello World")
# Out:
# Loaded pretrained model gpt2-small into HookedTransformer

# %%
# generate text
output = model.generate("Barack Obama was", max_new_tokens=20)
print(output)
# Out:
# 100%|██████████| 20/20 [00:01<00:00, 19.51it/s]
# Barack Obama was not your average Muslim, according to 2000 statistics. Here are the top 10 Muslim shootings of all time
