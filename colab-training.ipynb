# %%
import torch
import os

# %%
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
    print(f"CUDA Capability: {torch.cuda.get_device_capability(0)}")
else:
    print("WARNING: No GPU detected! Go to Runtime > Change runtime type > Select GPU")
# Out:
# GPU Available: True
# GPU Name: Tesla T4
# GPU Memory: 14.56 GB
# CUDA Capability: (7, 5)

# %%
# !git clone https://github.com/sdswitz/mech-int.git
# Out:
# Cloning into 'mech-int'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 31 (delta 11), reused 26 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 179.04 KiB | 44.76 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
os.chdir("mech-int")
os.listdir()
# Out:
# ['inspect-features.ipynb',
#  '.gitignore',
#  '.git',
#  'train.py',
#  'sae.py',
#  'train_wandb.py',
#  'Untitled-1.ipynb',
#  'requirements.txt',
#  'Untitled-1 copy.ipynb',
#  'context.md']

# %%
# !pip install -r requirements.txt

# %%
# !python train.py
# Out:
# 2026-03-16 18:42:18.283650: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773686538.305572   17157 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773686538.312876   17157 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773686538.332615   17157 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773686538.332641   17157 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773686538.332644   17157 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773686538.332647   17157 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-16 18:42:18.337546: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# config.json: 100% 567/567 [00:00<00:00, 5.36MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: 100% 166M/166M [00:05<00:00, 31.8MB/s]
# tokenizer_config.json: 100% 396/396 [00:00<00:00, 2.65MB/s]
# tokenizer.json: 2.11MB [00:00, 141MB/s]
# special_tokens_map.json: 100% 99.0/99.0 [00:00<00:00, 946kB/s]
# Loaded pretrained model pythia-70m into HookedTransformer
# README.md: 7.46kB [00:00, 26.2MB/s]
# Resolving data files: 100% 80/80 [00:00<00:00, 23800.85it/s]
# Resolving data files: 100% 80/80 [00:00<00:00, 30120.68it/s]
# Saved checkpoint to activations_checkpoint_5000.pt (5000/50000 texts)
# Saved checkpoint to activations_checkpoint_10000.pt (10000/50000 texts)
# Saved checkpoint to activations_checkpoint_15000.pt (15000/50000 texts)
# Saved checkpoint to activations_checkpoint_20000.pt (20000/50000 texts)
# Saved checkpoint to activations_checkpoint_25000.pt (25000/50000 texts)
# Saved checkpoint to activations_checkpoint_30000.pt (30000/50000 texts)
# Saved checkpoint to activations_checkpoint_35000.pt (35000/50000 texts)
# Saved checkpoint to activations_checkpoint_40000.pt (40000/50000 texts)
# Saved checkpoint to activations_checkpoint_45000.pt (45000/50000 texts)
# Saved checkpoint to activations_checkpoint_50000.pt (50000/50000 texts)
# Traceback (most recent call last):
#   File "/content/mech-int/train.py", line 68, in <module>
#     torch.save(all_activations, ACTIVATIONS_PATH)
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 976, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 838, in _open_zipfile_writer
#     return container(name_or_buffer)  # type: ignore[arg-type]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 802, in __init__
#     torch._C.PyTorchFileWriter(
# RuntimeError: Parent directory activations does not exist.

# %%
from google.colab import files
files.download("training_metrics.csv")
files.download("sae_model.pt")
