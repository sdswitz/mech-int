# %%
import torch
import os

# %%
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
    print(f"CUDA Capability: {torch.cuda.get_device_capability(0)}")
else:
    print("WARNING: No GPU detected! Go to Runtime > Change runtime type > Select GPU")
# Out:
# GPU Available: True
# GPU Name: NVIDIA A100-SXM4-40GB
# GPU Memory: 39.49 GB
# CUDA Capability: (8, 0)

# %%
# !ls
# Out:
# mech-int  sample_data

# %%
# !git clone https://github.com/sdswitz/mech-int.git
# Out:
# fatal: destination path 'mech-int' already exists and is not an empty directory.

# %%
os.listdir()
os.chdir("mech-int")
# !ls
# Out:
#  colab-training.ipynb	  requirements.txt   train_wandb.py
#  context.md		  sae.py	    'Untitled-1 copy.ipynb'
#  inspect-features.ipynb   train.py	     Untitled-1.ipynb

# %%
# !pip install -r requirements.txt

# %%
# !ls
# Out:
#  colab-training.ipynb	  requirements.txt   train_wandb.py
#  context.md		  sae.py	    'Untitled-1 copy.ipynb'
#  inspect-features.ipynb   train.py	     Untitled-1.ipynb

# %%
# print line 101 from train.py
with open("train.py", "r") as f:
    lines = f.readlines()
    print(lines[100])
# Out:
#     loss = SAEloss(xhat, x, f, lam=3)

# %%
# !python train.py
# Out:
# 2026-03-16 20:18:57.463237: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-16 20:18:57.481778: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773692337.503865    2695 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773692337.511148    2695 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from google.colab import drive                                                
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
files.download("sae_model.pt")

# %%
os.listdir()
# Out:
# ['activations_checkpoint_50000.pt',
#  'sae_model.pt',
#  'inspect-features.ipynb',
#  '.gitignore',
#  'training_metrics.csv',
#  '.git',
#  'train.py',
#  'colab-training.ipynb',
#  'sae.py',
#  'activations',
#  'train_wandb.py',
#  'Untitled-1.ipynb',
#  'requirements.txt',
#  'Untitled-1 copy.ipynb',
#  'context.md',
#  '__pycache__']

# %%
# !ls training_metrics.csv
# Out:
# training_metrics.csv

# %%
# !cp sae_model.pt /content/drive/MyDrive/
